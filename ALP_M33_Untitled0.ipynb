# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyvieiramaciel7171-hue/INTED2025M/blob/main/ALP_M33_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ALGORÍTIMO E LÓGICA DE PROGRAMAÇÃO
##INTRODUÇÃO

# %% [markdown]
# #ALGORÍTIMO
#
# ##INTRODUÇÃO

# %%
VARIÁVEIS
a = 50
b = 15
print(a+b)

# %%
##TIPOS DE DADOS

int - inteiros - para números inteiro

float - flutuantes - para números com vírgula

str - string - para palavras e textos

bool - booleano - para binários - True ou False

# %%
x = int(input("digite um número: "))
y = float(input("digite um número com vírgula: "))
z = str(input("digite uma palavra: "))
w = bool(input("digite um binário: "))

# %%
print(x)
print(y)
print(z)
print(w)

# %%
#Entradas
número 1 = int("Digite o primeiro número:"))
número 2 = int("Digite o segundo número:"))


#Processamento
soma = numero1 + numero2
subt = numero1 - numero2
div = numero1/ numero2
mult = numero1 * numero2
resto = numero1 % numero2
expo = numero1 ** numero2

#Saída
print(f"Asoma é: {soma} ")
print(f"A subtração é: {subt}")
print(f"A divisão é: {div}")
print(f"A multiplicação é: {mult}")
print(f"O resto da divisão é: {resto}")
print(f"A exponencial é: {expo:.2e}")
# Out:
#   File "/tmp/ipython-input-3153785687.py", line 2
#     número 1 = int("Digite o primeiro número:"))
#                                                ^
# SyntaxError: unmatched ')'

# %%
1 - Crie um algoritmo, que receba o nome do usuário, e 3 notas, depois calcule a média na variável (média), e imprima na tela e seguinte frase:
O aluno (nome) está com (media) de média!

# %% [markdown]
# 1 - crie um algoritmo que receba em uma variável um nome, e em outra uma idade. (nome, idade) depois mostre na tela a seguinte frase:
#
# Eu sou o **nome** e tenho **idade** anos!

# %%
algoritmo "Exemplo_Nome_Idade"
var
   nome: caracter
   idade: inteiro
inicio
   escreva("Digite seu nome: ")
   leia(nome)

   escreva("Digite sua idade: ")
   leia(idade)

   escreva("Eu sou o ", nome, " e tenho ", idade, " anos!")
fimalgoritmo
